# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# importing the csv file

data = pd.read_csv("/Users/jestin/Library/CloudStorage/GoogleDrive-jestininc@gmail.com/.shortcut-targets-by-id/1FNs070gdQf_KDO7ApNEzqTnvPawARrkD/storage_1/coding/data scince/ML/projects/vscode/machine_learning_projects/Car_price_prediction/CarPrice_Assignment.csv")

data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# descrbe the data

data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# # EDA

# %%
# checking for duplicate values
data.duplicated().sum()
# Out:
# 0

# %%
# checking  for null values

data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# ### Outlier detection

# %%
# skewness of the data
num_data= data.select_dtypes(exclude =['object'])
num_data.skew()
# Out:
# car_ID              0.000000
# symboling           0.211072
# wheelbase           1.050214
# carlength           0.155954
# carwidth            0.904003
# carheight           0.063123
# curbweight          0.681398
# enginesize          1.947655
# boreratio           0.020156
# stroke             -0.689705
# compressionratio    2.610862
# horsepower          1.405310
# peakrpm             0.075159
# citympg             0.663704
# highwaympg          0.539997
# price               1.777678
# dtype: float64

# %%
# outlier detection

def boxplot(col):
    sns.boxplot(data[col])
    plt.show()

for i in data.select_dtypes(exclude =['object']).columns[0:]:
    boxplot(i)

# %%
# outlier treatment required for the following columns:
# peak rpm, hourse power, comperession, engine size have outliers

# %% [markdown]
# ### IQR Method for Outlier Treatment

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
data['peakrpm'].describe()
# Out:
# count     205.000000
# mean     5125.121951
# std       476.985643
# min      4150.000000
# 25%      4800.000000
# 50%      5200.000000
# 75%      5500.000000
# max      6600.000000
# Name: peakrpm, dtype: float64

# %%
Q1 = data['peakrpm'].quantile(0.25)
Q3 = data['peakrpm'].quantile(0.75)
IQR = Q3 - Q1
upper_limit = Q3+1.5* IQR
lower_limit = Q1 -1.5* IQR
data['peakrpm']= np.where(data['peakrpm']> upper_limit,upper_limit,data['peakrpm'])

# %%
data['peakrpm'].describe()
# Out:
# count     205.000000
# mean     5124.634146
# std       475.493024
# min      4150.000000
# 25%      4800.000000
# 50%      5200.000000
# 75%      5500.000000
# max      6550.000000
# Name: peakrpm, dtype: float64

# %%
data['horsepower'].describe()
# Out:
# count    205.000000
# mean     104.117073
# std       39.544167
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      288.000000
# Name: horsepower, dtype: float64

# %%
Q1 = 70.00
Q3 = 116.00
IQR = Q3 - Q1
upper_limit = Q3+1.5* IQR
lower_limit = Q1 - 1.5 * IQR
data['horsepower']= np.where(data['horsepower']>upper_limit,upper_limit,data['horsepower'])

# %%
data['compressionratio'].describe()
# Out:
# count    205.000000
# mean      10.142537
# std        3.972040
# min        7.000000
# 25%        8.600000
# 50%        9.000000
# 75%        9.400000
# max       23.000000
# Name: compressionratio, dtype: float64

# %%
Q1 = data['compressionratio'].quantile(0.25)
Q3 = data['compressionratio'].quantile(0.75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR
data['compressionratio'] = np.where(data['compressionratio']>upper_limit,upper_limit,data['compressionratio'])

# %%
data['enginesize'].describe()
# Out:
# count    205.000000
# mean     126.907317
# std       41.642693
# min       61.000000
# 25%       97.000000
# 50%      120.000000
# 75%      141.000000
# max      326.000000
# Name: enginesize, dtype: float64

# %%
Q1 = data['enginesize'].quantile(0.25)
Q3 = data['enginesize'].quantile(0.75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR
data['enginesize'] = np.where(data['enginesize']>upper_limit,upper_limit,data['enginesize'])

# %%
# outlier detection

def boxplot(col):
    sns.boxplot(data[col])
    plt.show()

for i in data.select_dtypes(exclude =['object']).columns[0:]:
    boxplot(i)

# %% [markdown]
# ## encoding
#
# #### we are using one hot encoder here as it is not in order - Nominal data

# %%
# object type columns

## CarName, CarName, CarName, doornumber, carbody, carbody, carbody, enginetype, enginetype, enginetype,

# %%
from sklearn.preprocessing import OneHotEncoder
One = OneHotEncoder()
data= data
